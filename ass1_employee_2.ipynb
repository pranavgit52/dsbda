# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv(r"employee_2.csv")
dataset
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017        NaN            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 1802  Bachelors         2014  Bangalore            3   25  Female          No
# 1803  Bachelors         2016  Bangalore            3   26  Female          No
# 1804  Bachelors         2016  Bangalore            3   26  Female          No
# 1805  Bachelors         2014  New Delhi            3   26    Male          No
# 1806  Bachelors         2014  Bangalore            3   28    Male          No
#
# ...

# %%
dataset.head(10)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017        NaN            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot    Salary
# 0                          0           0  171369.0
# ...

# %%
dataset.tail(10)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1797  Bachelors         2013       Pune            2   27  Female          No
# 1798    Masters         2015  Bangalore            3   27  Female          No
# 1799    Masters         2017       Pune            3   27  Female          No
# 1800  Bachelors         2016  Bangalore            3   27    Male          No
# 1801  Bachelors         2012  Bangalore            3   27    Male          No
# 1802  Bachelors         2014  Bangalore            3   25  Female          No
# 1803  Bachelors         2016  Bangalore            3   26  Female          No
# 1804  Bachelors         2016  Bangalore            3   26  Female          No
# 1805  Bachelors         2014  New Delhi            3   26    Male          No
# 1806  Bachelors         2014  Bangalore            3   28    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot    Salary
# 1797                          5           1   59557.0
# ...

# %%
dataset.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
dataset.head(11)
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0   Bachelors         2017  Bangalore            3   34    Male          No
# 1   Bachelors         2013       Pune            1   28  Female          No
# 2   Bachelors         2014  New Delhi            3   38  Female          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 4     Masters         2017        NaN            3   24    Male         Yes
# 5   Bachelors         2016  Bangalore            3   22    Male          No
# 6   Bachelors         2015  New Delhi            3   38    Male          No
# 7   Bachelors         2016  Bangalore            3   34  Female          No
# 8   Bachelors         2016       Pune            3   23    Male          No
# 9     Masters         2017  New Delhi            2   37    Male          No
# 10    Masters         2012  Bangalore            3   27    Male          No
#
#     ExperienceInCurrentDomain  LeaveOrNot    Salary
# ...

# %%
dataset[1:11]
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1   Bachelors         2013       Pune            1   28  Female          No
# 2   Bachelors         2014  New Delhi            3   38  Female          No
# 3     Masters         2016  Bangalore            3   27    Male          No
# 4     Masters         2017        NaN            3   24    Male         Yes
# 5   Bachelors         2016  Bangalore            3   22    Male          No
# 6   Bachelors         2015  New Delhi            3   38    Male          No
# 7   Bachelors         2016  Bangalore            3   34  Female          No
# 8   Bachelors         2016       Pune            3   23    Male          No
# 9     Masters         2017  New Delhi            2   37    Male          No
# 10    Masters         2012  Bangalore            3   27    Male          No
#
#     ExperienceInCurrentDomain  LeaveOrNot    Salary
# 1                           3           1  136993.0
# ...

# %%
dataset.tail(5)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1802  Bachelors         2014  Bangalore            3   25  Female          No
# 1803  Bachelors         2016  Bangalore            3   26  Female          No
# 1804  Bachelors         2016  Bangalore            3   26  Female          No
# 1805  Bachelors         2014  New Delhi            3   26    Male          No
# 1806  Bachelors         2014  Bangalore            3   28    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot    Salary
# 1802                          3           0  257493.0
# 1803                          4           0  208095.0
# 1804                          4           0   97346.0
# 1805                          4           0  360181.0
# 1806                          3           0  253430.0

# %%
dataset.shape
# Out:
# (1807, 10)

# %%
dataset.isnull().sum()
# Out:
# Education                     0
# JoiningYear                   0
# City                         14
# PaymentTier                   0
# Age                           0
# Gender                        8
# EverBenched                   0
# ExperienceInCurrentDomain     0
# LeaveOrNot                    0
# Salary                        9
# dtype: int64

# %%
dataset.isnull().sum().sum()
# Out:
# 31

# %%
dataset.iloc[11:20]
# Out:
#     Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 11  Bachelors         2016       Pune            3   34    Male          No
# 12  Bachelors         2018       Pune            3   32    Male         Yes
# 13  Bachelors         2016  Bangalore            3   39    Male          No
# 14  Bachelors         2012  Bangalore            3   37     NaN          No
# 15  Bachelors         2017  Bangalore            1   29    Male          No
# 16  Bachelors         2014        NaN            3   34  Female          No
# 17  Bachelors         2014       Pune            3   34    Male          No
# 18  Bachelors         2015       Pune            2   30  Female          No
# 19  Bachelors         2016        NaN            2   22     NaN          No
#
#     ExperienceInCurrentDomain  LeaveOrNot    Salary
# 11                          3           0       NaN
# 12                          5           1  324620.0
# ...

# %%
dataset.iloc[11:20 ,0:3]
# Out:
#     Education  JoiningYear       City
# 11  Bachelors         2016       Pune
# 12  Bachelors         2018       Pune
# 13  Bachelors         2016  Bangalore
# 14  Bachelors         2012  Bangalore
# 15  Bachelors         2017  Bangalore
# 16  Bachelors         2014        NaN
# 17  Bachelors         2014       Pune
# 18  Bachelors         2015       Pune
# 19  Bachelors         2016        NaN

# %%
dataset.iloc[11:20:2]
# Out:
#     Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 11  Bachelors         2016       Pune            3   34   Male          No
# 13  Bachelors         2016  Bangalore            3   39   Male          No
# 15  Bachelors         2017  Bangalore            1   29   Male          No
# 17  Bachelors         2014       Pune            3   34   Male          No
# 19  Bachelors         2016        NaN            2   22    NaN          No
#
#     ExperienceInCurrentDomain  LeaveOrNot    Salary
# 11                          3           0       NaN
# 13                          2           0  347303.0
# 15                          3           0  144971.0
# 17                          4           0       NaN
# 19                          0           1  245955.0

# %%
dataset.iloc[[1,6,3,9,13,2],[1,4]]
# Out:
#     JoiningYear  Age
# 1          2013   28
# 6          2015   38
# 3          2016   27
# 9          2017   37
# 13         2016   39
# 2          2014   38

# %%
dataset.notnull().sum()
# Out:
# Education                    1807
# JoiningYear                  1807
# City                         1793
# PaymentTier                  1807
# Age                          1807
# Gender                       1799
# EverBenched                  1807
# ExperienceInCurrentDomain    1807
# LeaveOrNot                   1807
# Salary                       1798
# dtype: int64

# %%
fd=dataset.replace({"Male","Female"},{0,1})
fd
# Out:
# C:\Users\Victus\AppData\Local\Temp\ipykernel_17320\1603391449.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   fd=dataset.replace({"Male","Female"},{0,1})
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34     1.0          No
# 1     Bachelors         2013       Pune            1   28     0.0          No
# 2     Bachelors         2014  New Delhi            3   38     0.0          No
# 3       Masters         2016  Bangalore            3   27     1.0          No
# 4       Masters         2017        NaN            3   24     1.0         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# ...

# %%
sorted_dataset = dataset.sort_values("City")
print(sorted_dataset)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34   Male          No
# 951   Bachelors         2014  Bangalore            3   25   Male          No
# 959   Bachelors         2015  Bangalore            3   26   Male          No
# 961         PHD         2016  Bangalore            3   27   Male          No
# 962   Bachelors         2018  Bangalore            3   24   Male          No
# ...         ...          ...        ...          ...  ...    ...         ...
# 1676        PHD         2017        NaN            3   27   Male          No
# 1690  Bachelors         2017        NaN            2   25   Male          No
# 1692  Bachelors         2017        NaN            3   26   Male          No
# 1707    Masters         2017        NaN            2   26   Male          No
# 1719  Bachelors         2015        NaN            3   26   Male          No
#
# ...

# %%
dataset.dtypes
# Out:
# Education                     object
# JoiningYear                    int64
# City                          object
# PaymentTier                    int64
# Age                            int64
# Gender                        object
# EverBenched                   object
# ExperienceInCurrentDomain      int64
# LeaveOrNot                     int64
# Salary                       float64
# dtype: object

# %%
fd=dataset["Salary"]=dataset["Salary"].astype("float")
fd
# Out:
# 0       171369.0
# 1       136993.0
# 2       113807.0
# 3       166478.0
# 4       393136.0
#           ...
# 1802    257493.0
# 1803    208095.0
# 1804     97346.0
# 1805    360181.0
# 1806    253430.0
# Name: Salary, Length: 1807, dtype: float64

# %%
dataset.fillna(0)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017          0            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 1802  Bachelors         2014  Bangalore            3   25  Female          No
# 1803  Bachelors         2016  Bangalore            3   26  Female          No
# 1804  Bachelors         2016  Bangalore            3   26  Female          No
# 1805  Bachelors         2014  New Delhi            3   26    Male          No
# 1806  Bachelors         2014  Bangalore            3   28    Male          No
#
# ...

# %%
dataset.fillna(3)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017          3            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 1802  Bachelors         2014  Bangalore            3   25  Female          No
# 1803  Bachelors         2016  Bangalore            3   26  Female          No
# 1804  Bachelors         2016  Bangalore            3   26  Female          No
# 1805  Bachelors         2014  New Delhi            3   26    Male          No
# 1806  Bachelors         2014  Bangalore            3   28    Male          No
#
# ...

# %%
dataset.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  1807.000000  1807.000000  1807.000000                1807.000000
# mean   2015.076923     2.695075    26.310459                   3.228002
# std       1.854077     0.564248     2.142854                   1.302112
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     2.000000    25.000000                   2.000000
# 50%    2015.000000     3.000000    26.000000                   3.000000
# 75%    2017.000000     3.000000    27.000000                   4.000000
# max    2018.000000     3.000000    40.000000                   5.000000
#
#         LeaveOrNot         Salary
# count  1807.000000    1798.000000
# mean      0.362479  224240.323693
# std       0.480849  100823.365853
# min       0.000000   50135.000000
# 25%       0.000000  137712.250000
# 50%       0.000000  226605.500000
# 75%       1.000000  309474.000000
# max       1.000000  399785.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1807 entries, 0 to 1806
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  1807 non-null   object
#  1   JoiningYear                1807 non-null   int64
#  2   City                       1793 non-null   object
#  3   PaymentTier                1807 non-null   int64
#  4   Age                        1807 non-null   int64
#  5   Gender                     1799 non-null   object
#  6   EverBenched                1807 non-null   object
#  7   ExperienceInCurrentDomain  1807 non-null   int64
#  8   LeaveOrNot                 1807 non-null   int64
#  9   Salary                     1798 non-null   float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 141.3+ KB

# %%
dataset.fillna(dataset["Age"].mean())
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017  26.310459            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 1802  Bachelors         2014  Bangalore            3   25  Female          No
# 1803  Bachelors         2016  Bangalore            3   26  Female          No
# 1804  Bachelors         2016  Bangalore            3   26  Female          No
# 1805  Bachelors         2014  New Delhi            3   26    Male          No
# 1806  Bachelors         2014  Bangalore            3   28    Male          No
#
# ...

# %%
dataset.fillna(dataset["Salary"].median())
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017   226605.5            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 1802  Bachelors         2014  Bangalore            3   25  Female          No
# 1803  Bachelors         2016  Bangalore            3   26  Female          No
# 1804  Bachelors         2016  Bangalore            3   26  Female          No
# 1805  Bachelors         2014  New Delhi            3   26    Male          No
# 1806  Bachelors         2014  Bangalore            3   28    Male          No
#
# ...

# %%
m=dataset["Salary"].median()
dataset["Salary"].fillna(m)
# Out:
# 0       171369.0
# 1       136993.0
# 2       113807.0
# 3       166478.0
# 4       393136.0
#           ...
# 1802    257493.0
# 1803    208095.0
# 1804     97346.0
# 1805    360181.0
# 1806    253430.0
# Name: Salary, Length: 1807, dtype: float64

# %%
m=dataset["Salary"].mode()
dataset["Salary"].fillna(m)
# Out:
# 0       171369.0
# 1       136993.0
# 2       113807.0
# 3       166478.0
# 4       393136.0
#           ...
# 1802    257493.0
# 1803    208095.0
# 1804     97346.0
# 1805    360181.0
# 1806    253430.0
# Name: Salary, Length: 1807, dtype: float64
